# %% [markdown]
# # EfficientEEGEncoder v2 — Subject-Dependent Training (Colab)
#
# **Aligned with `train_efficient.py` SD recipe** (same as Kaggle/script):
# - **Optimizer:** Adam (no weight decay); L2 via `model.get_l2_loss()`
# - **Label smoothing:** 0.2
# - **LR:** Constant 1e-3 (no cosine schedule)
# - **Augmentation:** OFF for SD (best accuracy)
# - **Model:** `efficient_eegencoder.py` — no changes needed; same architecture as script
#
# **If Colab disconnects:** Re-run the training cell (inline or script). Both auto-resume from checkpoint.
#
# **Prerequisites:** Run `colab_preprocess_gdf.ipynb` first to create `.pkl` files.

# %%
# Cell 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cell 2: Install dependencies
# !pip install -q torch scikit-learn scipy

# %%
# Cell 3: Copy code (model + training script) and verify import
# !cp /content/drive/MyDrive/eegencoder/efficient_eegencoder.py /content/
# !cp /content/drive/MyDrive/eegencoder/train_efficient.py /content/

import sys
sys.path.insert(0, '/content')
from efficient_eegencoder import EfficientEEGEncoder, count_parameters, model_summary
print("Model imported successfully")
model_summary()
# Out:
# Model imported successfully
# Component                               Params
# -----------------------------------------------
#   augmentation                               0
#   conv_block                            18,272
#   branch_dropout                             0
#   tcn_blocks                            83,840
#   shared_transformer                    16,544
#   classifiers                              660
# -----------------------------------------------
#   TOTAL                                119,316
# 119316

# %% [markdown]
# **Alternative: Run SD via `train_efficient.py` (same as Kaggle)**
# Use this cell instead of Cell 4 if you want to run the exact script. Checkpoints go to `checkpoints_v2/sd/`; results to `results_v2/results_sd.json`.

# %%
# Run SD using train_efficient.py (same recipe as Kaggle; re-run to resume)
import sys
import os

DATA_DIR = '/content/drive/MyDrive/eegencoder/data/'
CHECKPOINT_DIR = '/content/drive/MyDrive/eegencoder/checkpoints_v2'
RESULTS_DIR = '/content/drive/MyDrive/eegencoder/results_v2'

import train_efficient as te
te.DEFAULT_CONFIG["data_dir"] = DATA_DIR
te.DEFAULT_CONFIG["checkpoint_dir"] = CHECKPOINT_DIR
te.DEFAULT_CONFIG["results_dir"] = RESULTS_DIR

sys.argv = [
    "train_efficient.py",
    "--mode", "sd",
    "--data_dir", DATA_DIR,
    "--checkpoint_dir", CHECKPOINT_DIR,
    "--results_dir", RESULTS_DIR,
]
te.main()
# Out:
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (102.0 GB)
#
# Config:
#   data_dir: /content/drive/MyDrive/eegencoder/data/
#   checkpoint_dir: /content/drive/MyDrive/eegencoder/checkpoints_v2
#   results_dir: /content/drive/MyDrive/eegencoder/results_v2
#   n_classes: 4
#   n_channels: 22
#   n_timepoints: 1125
#   n_branches: 5
#   hidden_size: 32
#   num_heads: 2
#   num_transformer_layers: 2
#   intermediate_size: 32
#   tcn_depth: 2
#   tcn_kernel_size: 4
#   tcn_filters: 32
#   dropout: 0.3
#   use_gradient_checkpoint: False
#   n_subjects: 9
#   n_epochs: 500
#   batch_size: 64
#   lr: 0.001
#   weight_decay: 0.01
#   warmup_epochs: 10
#   label_smoothing: 0.1
#   grad_clip_norm: 1.0
#   loss_scale_factor: 2.0
#   checkpoint_every: 50
#   seed: 32
#   loso_epochs: 600
#   use_ea: True
#   use_augmentation: True
#   num_workers: 2
#   use_amp: True
#
# ...
#   SUBJECT-DEPENDENT TRAINING — EfficientEEGEncoder
# ...
#
# --- Subject 1 ---
#   Parameters: 119,316
# ...

# %%
# Inline SD training — same recipe as train_efficient.py (Adam, label_smooth=0.2, explicit L2, no scheduler, no aug)
# Re-run this cell if Colab disconnects; it auto-resumes from checkpoint.
import math
import json
import os
import pickle
import random
import time

import numpy as np
import torch
import torch.nn as nn
from sklearn.metrics import accuracy_score, cohen_kappa_score
from torch.utils.data import DataLoader, Dataset

import sys
sys.path.insert(0, '/content')
from efficient_eegencoder import EfficientEEGEncoder, count_parameters

# ==================== CONFIGURATION ====================
DATA_DIR = '/content/drive/MyDrive/eegencoder/data/'
CHECKPOINT_DIR = '/content/drive/MyDrive/eegencoder/checkpoints_v2/sd/'
RESULTS_DIR = '/content/drive/MyDrive/eegencoder/results_v2/'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
N_SUBJECTS = 9
N_EPOCHS = 500
BATCH_SIZE = 64
LR = 1e-3
LABEL_SMOOTHING = 0.2
GRAD_CLIP = 1.0
LOSS_SCALE = 2.0
CHECKPOINT_EVERY = 50
SEED = 32
USE_AMP = True
QUICK_TEST = False  # Set True for 1 subject, 50 epochs

if QUICK_TEST:
    N_SUBJECTS = 1
    N_EPOCHS = 50
    print("QUICK TEST MODE: 1 subject, 50 epochs")

print(f"Device: {DEVICE}")
if DEVICE == 'cuda':
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# ==================== REPRODUCIBILITY ====================
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

def save_rng_state():
    return {
        'python': random.getstate(),
        'numpy': np.random.get_state(),
        'torch': torch.random.get_rng_state(),
        'cuda': torch.cuda.get_rng_state_all() if torch.cuda.is_available() else None,
    }

def load_rng_state(state):
    random.setstate(state['python'])
    np.random.set_state(state['numpy'])
    torch.random.set_rng_state(state['torch'])
    if state['cuda'] is not None and torch.cuda.is_available():
        torch.cuda.set_rng_state_all(state['cuda'])

seed_everything(SEED)

# ==================== DATA ====================
class EEGDataset(Dataset):
    def __init__(self, pkl_path, split='train'):
        with open(pkl_path, 'rb') as f:
            X_train, X_test, y_train_oh, y_test_oh = pickle.load(f)
        if split == 'train':
            self.x = torch.tensor(X_train, dtype=torch.float32)
            self.y = torch.tensor(y_train_oh, dtype=torch.float32)
        else:
            self.x = torch.tensor(X_test, dtype=torch.float32)
            self.y = torch.tensor(y_test_oh, dtype=torch.float32)
    def __len__(self): return len(self.x)
    def __getitem__(self, idx): return self.x[idx], self.y[idx]

# ==================== CHECKPOINT ====================
def save_checkpoint(path, model, optimizer, scaler, epoch, best_acc, best_kappa, rng_state):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    torch.save({
        'epoch': epoch, 'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scaler_state_dict': scaler.state_dict() if scaler else None,
        'best_acc': best_acc, 'best_kappa': best_kappa, 'rng_state': rng_state,
    }, path)

def load_checkpoint(path, model, optimizer, scaler, device):
    ckpt = torch.load(path, map_location=device, weights_only=False)
    model.load_state_dict(ckpt['model_state_dict'])
    optimizer.load_state_dict(ckpt['optimizer_state_dict'])
    if scaler and ckpt.get('scaler_state_dict'):
        scaler.load_state_dict(ckpt['scaler_state_dict'])
    if ckpt.get('rng_state'):
        load_rng_state(ckpt['rng_state'])
    return ckpt['epoch'], ckpt['best_acc'], ckpt['best_kappa']

# ==================== TRAIN / EVAL ====================
def train_one_epoch(model, loader, optimizer, scaler, loss_fn, device):
    model.train()
    preds_all, labels_all, loss_sum, n = [], [], 0.0, 0
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad(set_to_none=True)
        if scaler:
            with torch.amp.autocast('cuda'):
                logits = model(inputs)
                cls_loss = loss_fn(logits, labels)
                l2_loss = model.get_l2_loss()
                loss = cls_loss + l2_loss
            scaler.scale(loss * LOSS_SCALE).backward()
            if GRAD_CLIP > 0:
                scaler.unscale_(optimizer)
                nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
            scaler.step(optimizer)
            scaler.update()
        else:
            logits = model(inputs)
            cls_loss = loss_fn(logits, labels)
            l2_loss = model.get_l2_loss()
            loss = cls_loss + l2_loss
            (loss * LOSS_SCALE).backward()
            if GRAD_CLIP > 0:
                nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
            optimizer.step()
        preds_all.extend(logits.argmax(-1).cpu().numpy().tolist())
        labels_all.extend(labels.argmax(-1).cpu().numpy().tolist())
        loss_sum += cls_loss.item(); n += 1
    return accuracy_score(labels_all, preds_all), loss_sum / max(n, 1)

@torch.no_grad()
def evaluate(model, loader, device, scaler=None):
    model.eval()
    preds_all, labels_all, t_total = [], [], 0.0
    for inputs, labels in loader:
        inputs = inputs.to(device)
        t0 = time.time()
        if scaler:
            with torch.amp.autocast('cuda'):
                logits = model(inputs)
        else:
            logits = model(inputs)
        t_total += time.time() - t0
        preds_all.extend(logits.argmax(-1).cpu().numpy().tolist())
        labels_all.extend(labels.argmax(-1).cpu().numpy().tolist())
    return accuracy_score(labels_all, preds_all), cohen_kappa_score(labels_all, preds_all), t_total

# ==================== TRAIN ONE SUBJECT ====================
def train_subject(sub_idx):
    sub_id = sub_idx + 1
    ckpt_dir = os.path.join(CHECKPOINT_DIR, f'subject_{sub_id}')
    latest_path = os.path.join(ckpt_dir, 'latest.pt')
    best_path = os.path.join(ckpt_dir, 'best.pt')

    pkl_path = os.path.join(DATA_DIR, f'data_all_{sub_id}.pkl')
    train_ds = EEGDataset(pkl_path, 'train')
    val_ds = EEGDataset(pkl_path, 'val')
    nw = 2 if DEVICE == 'cuda' else 0
    pin = DEVICE == 'cuda'
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                              num_workers=nw, pin_memory=pin)
    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False,
                            num_workers=nw, pin_memory=pin)

    model = EfficientEEGEncoder(
        n_classes=4, apply_softmax=True, dense_wd=0.5,
        use_augmentation=False   # SD: no aug for best accuracy; LOSO keeps aug ON
    ).to(DEVICE)
    # Adam (not AdamW) — matching reference; L2 is handled via model.get_l2_loss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    scaler = torch.amp.GradScaler('cuda') if (USE_AMP and DEVICE == 'cuda') else None
    loss_fn = nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTHING)

    start_epoch, best_acc, best_kappa = 0, 0.0, 0.0
    if os.path.exists(latest_path):
        print(f"  Resuming from checkpoint...")
        start_epoch, best_acc, best_kappa = load_checkpoint(
            latest_path, model, optimizer, scaler, DEVICE)
        start_epoch += 1
        print(f"  Continuing at epoch {start_epoch}, best_acc={best_acc:.4f}")

    if sub_idx == 0:
        print(f"  Parameters: {count_parameters(model):,}")

    for epoch in range(start_epoch, N_EPOCHS):
        train_acc, train_loss = train_one_epoch(
            model, train_loader, optimizer, scaler, loss_fn, DEVICE)
        val_acc, kappa, _ = evaluate(model, val_loader, DEVICE, scaler)

        improved = val_acc > best_acc
        if improved:
            best_acc = val_acc
            best_kappa = kappa
            save_checkpoint(best_path, model, optimizer, scaler,
                            epoch, best_acc, best_kappa, save_rng_state())

        if (epoch + 1) % CHECKPOINT_EVERY == 0 or epoch == N_EPOCHS - 1:
            save_checkpoint(latest_path, model, optimizer, scaler,
                            epoch, best_acc, best_kappa, save_rng_state())

        if (epoch + 1) % 50 == 0 or epoch == 0 or improved:
            lr = optimizer.param_groups[0]['lr']
            star = ' *' if improved else ''
            print(f"  E{epoch+1:>4d}/{N_EPOCHS} | loss={train_loss:.4f} lr={lr:.2e} | "
                  f"train={train_acc:.4f} val={val_acc:.4f} "
                  f"kappa={kappa:.4f} best={best_acc:.4f}{star}")

    return best_acc, best_kappa

# ==================== RUN ALL SUBJECTS ====================
results = []
for s in range(N_SUBJECTS):
    print(f"\n{'='*60}")
    print(f"  Subject {s + 1}")
    print(f"{'='*60}")
    acc, kappa = train_subject(s)
    results.append({'subject': s + 1, 'accuracy': acc, 'kappa': kappa})
    print(f"  Subject {s+1}: Acc={acc:.4f}, Kappa={kappa:.4f}")

# ==================== RESULTS ====================
mean_acc = np.mean([r['accuracy'] for r in results])
mean_kappa = np.mean([r['kappa'] for r in results])
print(f"\n{'='*60}")
print(f"  EFFICIENT EEGENCODER v2 RESULTS (Subject-Dependent)")
print(f"{'='*60}")
print(f"  {'Subject':<10} {'Accuracy':>10} {'Kappa':>10}")
print(f"  {'-'*32}")
for r in results:
    print(f"  S{r['subject']:<9} {r['accuracy']:>10.4f} {r['kappa']:>10.4f}")
print(f"  {'-'*32}")
print(f"  {'Mean':<10} {mean_acc:>10.4f} {mean_kappa:>10.4f}")
print(f"\n  Paper baseline:  86.46% acc, 0.82 kappa")
print(f"  Your baseline:   84.72% acc, 0.80 kappa")
print(f"  Efficient v2:    {mean_acc*100:.2f}% acc, {mean_kappa:.2f} kappa")

os.makedirs(RESULTS_DIR, exist_ok=True)
with open(os.path.join(RESULTS_DIR, 'results_sd.json'), 'w') as f:
    json.dump({'results': results, 'mean_accuracy': mean_acc, 'mean_kappa': mean_kappa}, f, indent=2)
print(f"  Results saved to {RESULTS_DIR}results_sd.json")
